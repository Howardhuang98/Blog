# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_excel(r"C:\Users\admin\iCloudDrive\学习资料\贝叶斯网络科研\基于专家信息融合的贝叶斯网络的可靠性分析方法\罗\expert_knowledge2.xlsx",index_col=0)

# %%
plt.figure(dpi=600,figsize=[20,20])
sns.heatmap(data,
           cmap=plt.get_cmap('Blues'),
            square=True,
            linewidths=1,
            xticklabels=True,
            annot=True,
            cbar=False
            
   )
plt.savefig("rrr.png")
